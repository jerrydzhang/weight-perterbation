# %%
import numpy as np
import matplotlib.pyplot as plt

import utils.visualize as viz
from utils.ode import map_equation, hydrogen_bromine, hydrogen_bromine_init

# %load_ext autoreload
# %autoreload 2

# %%
dt = 0.002
visualize = viz.ODEResultVisualizer(
    fun=hydrogen_bromine,
    x0=[1.28765293e-09, 7.25644133e-10, 1.65047091e-09, 8.16685447e-15, 1.66990500e-08, 1.00000000e-05],
    t=np.arange(0, 9, dt),
    result_dir="../experiments/results/hbr_skip_stiff_20251008-112728",
    labels=["Br2", "Br", "H2", "H", "HBr", "M"],
)
visualize.solve()

# %%
visualize.plot_solution()

# %%
visualize.plot_metric_distribution('nmse_mean')

# %%
df = visualize.results_df
df.to_csv('temp_data.csv', index=False)

# %%
visualize.plot_parameter_heatmap(
    param_x="model_alpha",
    param_y="weight_eps",
    metric="nmse_mean",
    fixed_params={'weight_std': 0},
    save=True
)
# Out:
# Heatmap saved to heatmap_model_alpha_weight_eps_nmse_mean.png

# %%
df = visualize.results_df
df.to_csv('temp_data.csv', index=False)

# %%
visualize.get_best_model('nmse_mean', fixed_params={'weight_std': 0})
# Out:
# model                                     14_model
# nmse_0                                    0.003235
# nmse_1                                      0.0002
# nmse_2                                    0.000087
# nmse_3                                    0.001747
# nmse_4                                    0.000003
# nmse_5                                         0.0
# nmse_mean                                 0.000879
# data_file      hydrogen_bromine_ode_skip_stiff.csv
# equation                          hydrogen_bromine
# model_alpha                               0.000001
# weight_eps                                0.000006
# weight_std                                     0.0
# Name: 67, dtype: object

# %%
# visualize.plot_best_model_solution('nmse_mean', fixed_params={'weight_std': 0})
model = "13_model"
visualize.plot_model_solution(model, save=True)
# Out:
# Solution plot saved to solution_13_model_Br2.png
# Solution plot saved to solution_13_model_Br.png
# Solution plot saved to solution_13_model_H2.png
# Solution plot saved to solution_13_model_H.png
# Solution plot saved to solution_13_model_HBr.png
# Solution plot saved to solution_13_model_M.png

# %%
# visualize.plot_best_model_coefficients('nmse_mean', fixed_params={'weight_std': 0})
visualize.plot_coefficients(model, save=True)
# Out:
# Coefficient plot saved to coefficients_13_model.png
